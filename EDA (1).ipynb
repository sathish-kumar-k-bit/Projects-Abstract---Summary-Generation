# %% [markdown]
# # Contents
# 1. Importing Libraries
# 2. Preparing Data
# 3. Data Cleaning<br>
#     a. Removing extra spaces<br>
#     b. Removing stopwords<br>
#     c. Removing punctuations<br>
#     d. Lemmetizing to root form<br>
# 4. Data Visualization

# %% [markdown]
# # 1. Importing Libraries

# %%
# importing required modules
import PyPDF2
import pandas as pd
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter  #process_pdf
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
import re
from io import StringIO
from nltk.corpus import stopwords
import string
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from plotly.offline import init_notebook_mode, iplot
import cufflinks as cf

# %% [markdown]
# # 2. Preparing data

# %% [markdown]
# create_df() creates a dataframe containing the book title and author information

# %%
# Creating a dataframe to Store information about books
author = []
title = []
def create_df(new_author, new_title):
    author.append(new_author)
    title.append(new_title)
    df = pd.DataFrame(zip(title,author), columns = ['Title','Author'])
    return df

# %% [markdown]
# extract_information() returns the number of pages in the book

# %%
# Extracting number of pages
from PyPDF2 import PdfFileReader

def extract_information(pdf_path):
    with open(pdf_path, 'rb') as f:
        pdf = PdfFileReader(f)
        information = pdf.getDocumentInfo()
        number_of_pages = pdf.getNumPages()
    return number_of_pages

# %% [markdown]
# pdf_to_text() reads the book in pdf format and returns it as a text

# %%
# Extracting text
def pdf_to_text(pdfname):

    # PDFMiner boilerplate
    rsrcmgr = PDFResourceManager()
    sio = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, sio, laparams=laparams)
    interpreter = PDFPageInterpreter(rsrcmgr, device)

    # Extract text
    fp = open(pdfname, 'rb')
    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
    fp.close()

    # Get text from StringIO
    text = sio.getvalue()

    # Cleanup
    device.close()
    sio.close()

    return text

# %% [markdown]
# ### Converting pdf to text

# %%
path = 'books/Rich Dad Poor Dad.pdf'
num_pages = []
num_pages.append(extract_information(path) )
text = []
text.append(pdf_to_text(path))
df = create_df('Robert Kiyosaki and Sharon Lechter','Rich Dad Poor Dad')

# %%
len(text[0])
# Out:
# 376691

# %%
text[0][:100]
# Out:
# 'What The Rich Teach Their Kids About Money – \n\nThat The Poor And Middle Class Do Not!\n\nRobert T. Kiy'

# %%
path = 'books/An Imaginary Tale_ The Story of i the square root of minus one.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Paul J. Nahin','An Imaginary Tale_ The Story of i the square root of minus one')

# %%
path = 'books/Boundaries_ When to Say Yes, How to Say No to Take Control of Your Life.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Henry Cloud, John Townsend','Boundaries_ When to Say Yes, How to Say No to Take Control of Your Life')

# %%
path = 'books/Evil_ The Science Behind Humanity’s Dark Side.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Julia Shaw','Evil_ The Science Behind Humanity’s Dark Side')

# %%
path = 'books/Fallen_Angels_and_the_Origins_of_Evil_Elizabeth_Clare_Prophet.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Elizabeth Clare Prophet','Fallen_Angels_and_the_Origins_of_Evil_Elizabeth_Clare_Prophet')
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
path = 'books/Harry Potter ve Ateş Kadehi - J. K. Rowling.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('J.K. Rowling','Harry Potter ve Ateş Kadehi - J. K. Rowling')

# %%
path = 'books/Living in the Light.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Shakti Gawain','Living in the Light')

# %%
path = 'books/See You At The Top.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Zig Ziglar','See You At The Top')

# %%
path = 'books/Sentiment in the Forex Market_ Indicators and Strategies To Profit from Crowd Behavior and Market Extremes.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Jamie Saettele','Sentiment in the Forex Market_ Indicators and Strategies To Profit from Crowd Behavior and Market Extremes')

# %%
path = 'books/Start Where You Are_ A Guide to Compassionate Living.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Pema Chodron','Start Where You Are_ A Guide to Compassionate Living')

# %%
path = 'books/Subliminal Psychology 101_ How to Stealthily Penetrate, Influence, and Subdue Anyone’s Mind Without Them Suspecting a Thing.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Michael Pace','Subliminal Psychology 101_ How to Stealthily Penetrate, Influence, and Subdue Anyone’s Mind Without Them Suspecting a Thing')

# %%
path = 'books/The Dark Side of Personality_ Science and Practice in Social, Personality, and Clinical Psychology.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Virgil Zeiglar-Hill, David K. Marcus','The Dark Side of Personality_ Science and Practice in Social, Personality, and Clinical Psychology')

# %%
path = 'books/the-time-machine.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('H. G. Wells','The Time Machine')

# %%
path = 'books/world-of-warcraft-2009-arthas-rise-of-the-lich-king-christie-golden.pdf'
num_pages.append(extract_information(path) )
text.append(pdf_to_text(path))
df = create_df('Christie Golden','World of Warcraft - Arthas Rise of the Lich king')

# %% [markdown]
# ### Final Dataframe

# %%
df['Number of Pages'] = num_pages
df['Text'] = text
df
# Out:
#                                                 Title  \
# 0                                   Rich Dad Poor Dad
# 1   An Imaginary Tale_ The Story of i the square r...
# 2   Boundaries_ When to Say Yes, How to Say No to ...
# 3       Evil_ The Science Behind Humanity’s Dark Side
# 4   Fallen_Angels_and_the_Origins_of_Evil_Elizabet...
# 5         Harry Potter ve Ateş Kadehi - J. K. Rowling
# 6                                 Living in the Light
# 7                                  See You At The Top
# 8   Sentiment in the Forex Market_ Indicators and ...
# 9   Start Where You Are_ A Guide to Compassionate ...
# 10  Subliminal Psychology 101_ How to Stealthily P...
# 11  The Dark Side of Personality_ Science and Prac...
# 12                                   The Time Machine
# 13   World of Warcraft - Arthas Rise of the Lich king
#
#                                   Author  Number of Pages  \
# 0     Robert Kiyosaki and Sharon Lechter              241
# 1                          Paul J. Nahin              297
# 2             Henry Cloud, John Townsend              357
# 3                             Julia Shaw              221
# 4                Elizabeth Clare Prophet              455
# 5                           J.K. Rowling              912
# 6                          Shakti Gawain              258
# 7                             Zig Ziglar              386
# 8                         Jamie Saettele              211
# 9                           Pema Chodron              242
# 10                          Michael Pace              141
# 11  Virgil Zeiglar-Hill, David K. Marcus              384
# 12                           H. G. Wells              120
# 13                       Christie Golden              212
#
#                                                  Text
# 0   What The Rich Teach Their Kids About Money – \...
# 1
#
# An Imaginary Tale\n\n
#
# An Imaginary Tale\n\n...
# 2
# Resources by Henry Cloud and John Townsend\n\...
# 3
# Also\tby\tDr.\tJulia\tShaw\n\nThe\tMemory\tIl...
# 4    \n\n1 \n\n
#  \n\n \n\n \n\n2 \n\n \n\n
#  \n\n \...
# 5
# Harry Potter\n\nve\n\nAteş Kadehi\n\nJ. K. Ro...
# 6
# LIL Quark-FM  1/22/01  8:42 AM  Page i\n\nLIV...
# 7
# I BELIEVE \n\nYou  can get everything  in  li...
# 8
# P1: a/b\nfm\n\nP2: c/d\n\nQC: e/f\n\nT1: g\n\...
# 9
# This page intentionally left blank.\nThis pag...
# 10
# Subliminal Psychology 101\nHow to Stealthily ...
# 11
# THE DARK SIDE  OF PERSONALITY
#
# THE DARK SIDE ...
# 12  The Time Machine  \n\nBy H. G. Wells\n\n
# Publi...
# 13  ORGANIZED BY CLOCKLI\r\n\n1\n\n
# World of WarCr...

# %%
df.shape
# Out:
# (14, 4)

# %%
df.isnull().sum()
# Out:
# Title              0
# Author             0
# Number of Pages    0
# Text               0
# dtype: int64

# %% [markdown]
# # 3. Data Cleaning

# %%
stemmer = PorterStemmer()
lemmetizer = WordNetLemmatizer()

# %%
stop_words = stopwords.words('english')

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
more_stop_words = ['\x0c','"','-','_','.']
stop_words.extend(more_stop_words)

# %% [markdown]
# clean_data() takes sentence separated string input and cleans the data i.e. removing stopwords and punctuation and returning lemmetized string output

# %%
def clean_data(text):
    re.sub(r'[\d]','',text)
    re.sub(r'[^a-zA-Z]','',text)
    re.sub('\s+',' ',text)
    text_clean = []
    text_tokens = word_tokenize(text)
    #text_tokens = tokenizer.tokenize(text)    
    for word in text_tokens:
        if (word not in stop_words and # remove stopwords
            word not in string.punctuation): # remove punctuation
            stem_word = lemmetizer.lemmatize(word) # stemming word
            text_clean.append(stem_word)
    
    list_to_str = ' '.join([str(ele) for ele in text_clean])
    return list_to_str.lower()

# %% [markdown]
# call_to_clean() takes full text as input, breaks them into sentences and calls the clean_data() with the separated sentences as arguments

# %%
clean_text = []
def call_to_clean(text):
    sentences = re.split(r'\n+',text)
    sentence_df = pd.DataFrame(sentences, columns = ['Text'])
    sentence_df['Text'] = sentence_df['Text'].apply(clean_data)
    clean_text.append(' '.join(sentence_df['Text']))

# %%
call_to_clean(df['Text'].loc[0])

# %%
clean_text[0][:200]
# Out:
# 'what the rich teach their kids about money – that the poor and middle class do not robert t. kiyosaki “ rich dad poor dad starting point anyone looking gain control financial future. ” – usa today wha'

# %%
for i in range(1,14):
    call_to_clean(df['Text'].loc[i])

# %%
clean_text[5][:200]
# Out:
# "harry potter  ateş kadehi j. k. rowling 2000 bi̇ri̇nci̇ bölüm riddle evi̇ riddle ailesi evde oturmayalı yıllar olduğu halde küçük hangleton köyü sakinleri ona hâlâ `` riddle evi '' diyordu ev köye hâk"

# %% [markdown]
# ### Cleaned Data

# %%
df['Clean Text'] = clean_text
df
# Out:
#                                                 Title  \
# 0                                   Rich Dad Poor Dad
# 1   An Imaginary Tale_ The Story of i the square r...
# 2   Boundaries_ When to Say Yes, How to Say No to ...
# 3       Evil_ The Science Behind Humanity’s Dark Side
# 4   Fallen_Angels_and_the_Origins_of_Evil_Elizabet...
# 5         Harry Potter ve Ateş Kadehi - J. K. Rowling
# 6                                 Living in the Light
# 7                                  See You At The Top
# 8   Sentiment in the Forex Market_ Indicators and ...
# 9   Start Where You Are_ A Guide to Compassionate ...
# 10  Subliminal Psychology 101_ How to Stealthily P...
# 11  The Dark Side of Personality_ Science and Prac...
# 12                                   The Time Machine
# 13   World of Warcraft - Arthas Rise of the Lich king
#
#                                   Author  Number of Pages  \
# 0     Robert Kiyosaki and Sharon Lechter              241
# 1                          Paul J. Nahin              297
# 2             Henry Cloud, John Townsend              357
# 3                             Julia Shaw              221
# 4                Elizabeth Clare Prophet              455
# 5                           J.K. Rowling              912
# 6                          Shakti Gawain              258
# 7                             Zig Ziglar              386
# 8                         Jamie Saettele              211
# 9                           Pema Chodron              242
# 10                          Michael Pace              141
# 11  Virgil Zeiglar-Hill, David K. Marcus              384
# 12                           H. G. Wells              120
# 13                       Christie Golden              212
#
#                                                  Text  \
# 0   What The Rich Teach Their Kids About Money – \...
# 1
#
# An Imaginary Tale\n\n
#
# An Imaginary Tale\n\n...
# 2
# Resources by Henry Cloud and John Townsend\n\...
# 3
# Also\tby\tDr.\tJulia\tShaw\n\nThe\tMemory\tIl...
# 4    \n\n1 \n\n
#  \n\n \n\n \n\n2 \n\n \n\n
#  \n\n \...
# 5
# Harry Potter\n\nve\n\nAteş Kadehi\n\nJ. K. Ro...
# 6
# LIL Quark-FM  1/22/01  8:42 AM  Page i\n\nLIV...
# 7
# I BELIEVE \n\nYou  can get everything  in  li...
# 8
# P1: a/b\nfm\n\nP2: c/d\n\nQC: e/f\n\nT1: g\n\...
# 9
# This page intentionally left blank.\nThis pag...
# 10
# Subliminal Psychology 101\nHow to Stealthily ...
# 11
# THE DARK SIDE  OF PERSONALITY
#
# THE DARK SIDE ...
# 12  The Time Machine  \n\nBy H. G. Wells\n\n
# Publi...
# 13  ORGANIZED BY CLOCKLI\r\n\n1\n\n
# World of WarCr...
#
#                                            Clean Text
# 0   what the rich teach their kids about money – t...
# 1   an imaginary tale an imaginary tale the story ...
# 2   resources henry cloud john townsend boundaries...
# 3   also dr. julia shaw the memory illusion copyri...
# 4    1    2       3 fallen angels and the origins ...
# 5   harry potter  ateş kadehi j. k. rowling 2000 b...
# 6   lil quark-fm 1/22/01 8:42 am page living the l...
# 7   i believe you get everything life want help en...
# 8   p1 a/b fm p2 c/d qc e/f t1 g jwbk195-saettele ...
# 9   this page intentionally left blank this page i...
# 10  subliminal psychology 101 how stealthily penet...
# 11  the dark side of personality the dark side of ...
# 12  the time machine by h. g. wells published plan...
# 13  organized by clockli 1 world warcraft arthas r...

# %%
# df.to_csv('processed_book_data.csv')

# %% [markdown]
# # 4. Visualization

# %% [markdown]
# ## a. WordCloud of Commonly used words in the book "Rich Dad Poor Dad"
# ### NOTE : We are using only "Rich Dad Poor Dad" to avoid crowding and for simplicity

# %%
sentences = sent_tokenize(df['Text'][0])
sentence_df = pd.DataFrame(sentences, columns = ['Text'])

# %%
# Generating a wordcloud
from wordcloud import WordCloud
allwords = " ".join([txt for txt in sentence_df["Text"]])
wordCloud = WordCloud(width = 1000, height = 1000, random_state = 42, max_font_size = 119).generate(allwords)
plt.figure(figsize=(20, 20), dpi=80)
plt.imshow(wordCloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ## b. Plotting n-grams

# %%
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# get_top_n_words() returns the n-grams. n can be specified by user

# %%
def get_top_n_words(corpus, ngrams,n=None):
    vec = CountVectorizer(ngram_range = (ngrams,ngrams),stop_words = 'english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
common_words = get_top_n_words(sentence_df['Text'],1, 20)
df2 = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
df2.groupby('ReviewText').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 words', colors= 'orange')
# Out:
# <div>                            <div id="b7030ec4-60a2-43ed-9dad-2ce34c1e71d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("b7030ec4-60a2-43ed-9dad-2ce34c1e71d7")) {                    Plotly.newPlot(                        "b7030ec4-60a2-43ed-9dad-2ce34c1e71d7",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"count","orientation":"v","text":"","type":"bar","x":["dad","money","rich","people","financial","work","said","poor","don","want","learn","life","know","just","make","pay","income","like","time","mike"],"y":[636,595,592,423,244,221,220,218,165,163,160,154,151,149,142,141,135,130,130,130]}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sca ...

# %% [markdown]
# #### Inference
# 1. This plot demonstrates top unigrams or single most frequent words in the book.
# 2. Since this book is related to finance and financial freedom, this plot lines perfectly with the theme.
# 3. Words like "dad", "money", "rich" are used very often

# %%
common_words_2 = get_top_n_words(sentence_df['Text'],2, 20)
df3 = pd.DataFrame(common_words_2, columns = ['ReviewText' , 'count'])
df3.groupby('ReviewText').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 bigrams', colors= 'purple')
# Out:
# <div>                            <div id="433c0247-452b-4e22-8819-cacc5f3cf1a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("433c0247-452b-4e22-8819-cacc5f3cf1a7")) {                    Plotly.newPlot(                        "433c0247-452b-4e22-8819-cacc5f3cf1a7",                        [{"marker":{"color":"rgba(128, 0, 128, 0.6)","line":{"color":"rgba(128, 0, 128, 1.0)","width":1}},"name":"count","orientation":"v","text":"","type":"bar","x":["rich dad","poor dad","dad poor","real estate","chapter lesson","middle class","asset column","cash flow","said rich","make money","financial intelligence","dad said","educated dad","poor middle","cashflow quadrant","work money","balance sheet","financial education","income statement","assets liabilities"],"y":[370,124,101,81,58,50,48,47,43,42,39,33,32,32,30,30,28,26,25,25]}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type" ...

# %% [markdown]
# #### Inference
# 1. words like "rich dad", "poor dad", "real estate" are used together very often
# 2. This plot demonstrates the frequent use of bigrams

# %%
common_words_3 = get_top_n_words(sentence_df['Text'],3, 20)
df4 = pd.DataFrame(common_words_3, columns = ['ReviewText' , 'count'])
df4.groupby('ReviewText').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 trigrams', colors= 'cyan')
# Out:
# <div>                            <div id="5591ee85-3a98-4b85-8752-68218501f0c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("5591ee85-3a98-4b85-8752-68218501f0c3")) {                    Plotly.newPlot(                        "5591ee85-3a98-4b85-8752-68218501f0c3",                        [{"marker":{"color":"rgba(0, 255, 255, 0.6)","line":{"color":"rgba(0, 255, 255, 1.0)","width":1}},"name":"count","orientation":"v","text":"","type":"bar","x":["dad poor dad","rich dad poor","said rich dad","poor middle class","rich dad said","balance sheet assets","income statement income","sheet assets liabilities","chapter getting started","difference asset liability","statement income expenses","10 cents hour","rich dad cashflow","dad cashflow quadrant","rich dad say","chapter seven overcoming","seven overcoming obstacles","real estate market","rich dad taught","cash flow pattern"],"y":[98,95,42,32,20,18,17,15,11,11,10,9,9,9,8,8,8,8,7,7]}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"} ...

# %% [markdown]
# #### Inference
# 1. This plot represents top 20 trigrams used in the book

# %% [markdown]
# ## c. Part of Speech

# %%
from textblob import TextBlob

# %%
import plotly.express as px

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(20,8))
blob = TextBlob(str(sentence_df['Text']))
pos_df = pd.DataFrame(blob.tags, columns = ['word' , 'pos'])
pos_df = pos_df.pos.value_counts()[:20]
sns.barplot(x=pos_df.keys(),y=pos_df.values)
plt.title('Top 20 Part-of-Speech tagging for corpus', fontsize = 24)
# pos_df.iplot(
#     kind='bar',
#     xTitle='POS',
#     yTitle='count', 
#     title='Top 20 Part-of-speech tagging for corpus')
# Out:
# Text(0.5, 1.0, 'Top 20 Part-of-Speech tagging for corpus')

# %% [markdown]
# #### Inference
# 1. This plot represents the frequency of occurance of part-of-speech in the book "Rich Dad Poor Dad"
# 2. Proper nouns are used most often in the book <br>
# #### labels =
# 1. 'NN': 'Noun'
# 2. 'CD': 'numeral, cardinal'
# 3. 'JJ': 'adjective or numeral ordinal'
# 4. 'NNS': 'noun, proper, singular'
# 5. 'DT': 'determiner'
# 6. 'VBP': 'verb, base,a plural'
# 7. 'IN': 'preposition or conjunction, subordinating'
# 8. 'WP':	'Wh-pronoun'
# 9. 'PRP$':	'Possessive pronoun'
# 10.  'VBG':	'Verb, gerund/present participle'
# 11. 'CC': 'conjunction, coordinating'
# 12. 'RB':	'Adverb'
# 13. 'VBD':	'Verb, past tense'
# 14. 'NNP': 'noun, proper, plural'

# %% [markdown]
# ## d. No. of pages

# %%
plt.figure(figsize=(30,8))
sns.barplot(x = df['Title'], y = df['Number of Pages'])
plt.xticks(rotation = 75, fontsize = 16)
plt.yticks(fontsize = 16)
plt.title('Number of pages in each book', fontsize = 24)
# Out:
# Text(0.5, 1.0, 'Number of pages in each book')

# %% [markdown]
# #### Inference
# 1. This plot represents the number of pages in each book
# 2. "Harry Potter vs Ates Kadehi" has highest no. of pages
# 3. "The Dark side of personality" contains least no. of pages

# %%
# Pie chart for total number of pages
labels = ['Rich Dad Poor Dad', 'An Imaginary Tale_ The Story of i the square root of minus one', 'Boundaries_ When to Say Yes, How to Say No to Take Control of Your Life', 'Evil_ The Science Behind Humanity’s Dark Side', 'Fallen_Angels_and_the_Origins_of_Evil_Elizabeth_Clare_Prophet', 'Harry Potter ve Ateş Kadehi - J. K. Rowling', 'Living in the Light', 'See You At The Top', 'Sentiment in the Forex Market_ Indicators and Strategies To Profit from Crowd Behavior and Market Extremes', 'Start Where You Are_ A Guide to Compassionate Living', 'Subliminal Psychology 101_ How to Stealthily Penetrate, Influence, and Subdue Anyone’s Mind Without Them Suspecting a Thing', 'The Dark Side of Personality_ Science and Practice in Social, Personality, and Clinical Psychology', 'The Time Machine', 'World of Warcraft - Arthas Rise of the Lich king']
sizes = [241, 297, 357, 221, 455, 912, 258, 386, 211, 242, 141, 384, 120, 212]
explode = [0.1]*14
#add colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
fig1, ax1 = plt.subplots(figsize = (15,10))
ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Inference
# 1. This plot is a better representative of the number of pages in each book.
# 2. Bigger pie represents greater no. of pages

# %% [markdown]
# ## e. Relationship between number of pages and length of text

# %%
df1 = df.copy()
len_text = []
for i in df['Text']:
    len_text.append(len(i))
df1['Length of Text'] = len_text

# %%
px.scatter(df1, x = 'Length of Text', y = 'Number of Pages', size = 'Number of Pages', size_max=60, color = 'Title', hover_name= 'Title')
# Out:
# <div>                            <div id="1a04ef89-b3c5-473d-ae08-510d8c18b8f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a04ef89-b3c5-473d-ae08-510d8c18b8f4")) {                    Plotly.newPlot(                        "1a04ef89-b3c5-473d-ae08-510d8c18b8f4",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Title=Rich Dad Poor Dad<br>Length of Text=%{x}<br>Number of Pages=%{marker.size}<extra></extra>","hovertext":["Rich Dad Poor Dad"],"legendgroup":"Rich Dad Poor Dad","marker":{"color":"#636efa","size":[241],"sizemode":"area","sizeref":0.25333333333333335,"symbol":"circle"},"mode":"markers","name":"Rich Dad Poor Dad","orientation":"v","showlegend":true,"type":"scatter","x":[376691],"xaxis":"x","y":[241],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Title=An Imaginary Tale_ The Story of i the square root of minus one<br>Length of Text=%{x}<br>Number of Pages=%{marker.size}<extra></extra>","hovertext":["An Imaginary Tale_ The Story of i the square root of minus one"],"legendgroup":"An Imaginary Tale_ The Story of i the square root of minus one","marker":{"color":"#EF553B","size":[297],"sizemode":"area","sizeref":0.25333333333333335,"symbol":"circle"},"mode":"markers","name":"An Imaginary Tale_ The Story of i the square root of minus one","orientation":"v","showlegend":true,"type":"scatter","x":[579858],"xaxis":"x","y":[297],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Title=Boundaries_ When to Say Yes, How to Say No to Take Control of Your Life<br>Length of Text=%{x}<br>Number of Pages=%{marker.size}<extra></extra>","hovertext":["Boundaries_ When to Say Yes, How to Say No to Take Control of Your Life"],"legendgroup":"Boundaries_ When to Say Yes, How to Say No to Take Control of Your Life","marker":{"color":"#00cc96","size":[357],"sizemode":"area","sizeref":0.25333333333333335,"symbol":"circle"},"mode":"markers","name":"Boundaries_ When to Say Yes, How to Say No to Take Control of Your Life","orientation":"v","showlegend":true,"type":"scatter","x":[670697],"xaxis":"x","y":[357],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Title=Evil_ The Science Behind Humanity\u2019s Dark Side<br>Length of Text=%{x}<br>Number of Pages=%{marker.size}<extra></extra>","hovertext":["Evil_ The Science Behind Humanity\u2019s Dark Side"],"legendgroup":"Evil_ The Science Behind Humanity\u2019s Dark Side","marker":{"color":"#ab63fa","size":[221],"sizemode":"area","sizeref":0.25333333333333335,"symbol":"circle"},"mode":"markers","name":"Evil_ The Science Behind Humanity\u2019s Dark Side","orientation":"v","showlegend":true,"type":"scatter","x":[480848],"xaxis":"x","y":[221],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Title=Fallen_Angels_and_the_Origins_of_Evil_Elizabeth_Clare_Prophet<br>Length of Text=%{x}<br>Number of Pages=%{marker.size}<extra></extra>","hovertext":["Fallen_Angels_and_the_Origins_of_Evil_Elizabeth_Clare_Prophet"],"legendgroup":"Fallen_Angels_and_the_Origins_of_Evil_Elizabeth_Clare_Prophet","marker":{"color":"#FFA15A","size":[455],"sizemode":"area","sizeref":0.25333333333333335,"symbol":"circle"},"mode":"markers","name":"Fallen_Angels_and_the_Origins_of_Evil_Elizabeth_Clare_Prophet","orientation":"v","showlegend":true,"type":"scatter","x":[640195],"xaxis":"x","y":[455],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Title=Harry Potter ve Ate\u015f Kadehi - J. K. Rowling<br>Length of Text=%{x}<br>Number of Pages=%{marker.size}<extra></extra>","hovertext":["Harry Potter ve Ate\u015f Kadehi - J. K. Rowling"],"legendgroup":"Harry Potter ve Ate\u015f Kadehi - J. K. Rowling","marker":{"color":"#19d3f3","size":[912],"sizemode":"area","sizeref":0.25333333333333335,"symbol":"circle"},"mode":"markers","name":"Harry Potter v ...

# %% [markdown]
# #### Inferences
# 1. This plot represents the relationship between length of text and number of pages in each book.
# 2. Bigger bubble represents higher number of pages.
# 3. Each color corresponds to different book.
# 4. Length of text is directly proportional to number of pages
# 5. It is interesting to note that "Fallen Angels and the Origins of Evil" has 455 number of pages which is higher than "See you at the Top" and "The Dark Side of Personality" but the Length of text in it is less. This indicates that bigger font was used while publishing the book.
# 6. "World of Warcraft" has around 0.6M words but the number of pages used was 212 as compared to "An Imaginary Tale-The Story of i the square root of minus one" which is 297. This indicates that the text might be closely oriented or smaller fontsize is used.
